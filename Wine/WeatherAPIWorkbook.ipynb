# %%
import requests as req
import json
import urllib

import pandas as pd

# %%
key = '6497d1ddf07d485cbda142938181603'

# %%
url = "http://api.worldweatheronline.com/premium/v1/weather.ashx?query=London&num_of_results=3&format=json&key="+key 
# url = "http://api.worldweatheronline.com/premium/v1/search.ashx?query=London&num_of_results=3&format=json&key="+key
url
# Out:
# 'http://api.worldweatheronline.com/premium/v1/weather.ashx?query=London&num_of_results=3&format=json&key=6497d1ddf07d485cbda142938181603'

# %%
response = req.get(url)

response
# Out:
# <Response [200]>

# %%
json_data = response.json()

json_data
# Out:
# {'data': {'ClimateAverages': [{'month': [{'absMaxTemp': '8.6',
#       'absMaxTemp_F': '47.5',
#       'avgDailyRainfall': '2.44',
#       'avgMinTemp': '2.4',
#       'avgMinTemp_F': '36.3',
#       'index': '1',
#       'name': 'January'},
#      {'absMaxTemp': '9.7',
#       'absMaxTemp_F': '49.5',
#       'avgDailyRainfall': '2.32',
#       'avgMinTemp': '2.4',
#       'avgMinTemp_F': '36.3',
#       'index': '2',
#       'name': 'February'},
#      {'absMaxTemp': '14.7',
#       'absMaxTemp_F': '58.5',
#       'avgDailyRainfall': '1.64',
#       'avgMinTemp': '3.6',
#       'avgMinTemp_F': '38.5',
#       'index': '3',
#       'name': 'March'},
#      {'absMaxTemp': '18.7',
#       'absMaxTemp_F': '65.7',
#       'avgDailyRainfall': '1.74',
#       'avgMinTemp': '5.9',
#       'avgMinTemp_F': '42.6',
#       'index': '4',
#       'name': 'April'},
#      {'absMaxTemp': '18.8',
#       'absMaxTemp_F': '65.8',
#       'avgDailyRainfall': '2.17',
#       'avgMinTemp': '9.6',
# ...

# %%
import json
import requests as req

# Save config information
api_key = "d9f788ccd230de9dfedc79a53db72d7f"
url = "http://api.openweathermap.org/data/2.5/weather?"
city = "Bujumbura"
# temp  =weather_json['main']['temp']

# Build query URL
celcius_url = url + "appid=" + api_key + "&q=" + city + "&units=metric"
fahr_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"
# Get weather data
c_response = req.get(celcius_url)
c_json = c_response.json()

f_response = req.get(fahr_url)
f_json = f_response.json()


# Get the temperature from the response
print("The temperature in celcius  in Bujumbura: " + str(c_json) + ".")
print("The temperature in Fahrenheit  in Bujumbura: " + str(f_json) + ".")
# Out:
# The temperature in celcius  in Bujumbura: {'coord': {'lon': 29.37, 'lat': -3.36}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 16.49, 'pressure': 857.46, 'humidity': 100, 'temp_min': 16.49, 'temp_max': 16.49, 'sea_level': 1025.44, 'grnd_level': 857.46}, 'wind': {'speed': 1.21, 'deg': 42.0011}, 'clouds': {'all': 76}, 'dt': 1521598099, 'sys': {'message': 0.0038, 'country': 'BI', 'sunrise': 1521605188, 'sunset': 1521648770}, 'id': 425378, 'name': 'Bujumbura', 'cod': 200}.
# ...

# %%
# will need to do something with unix time conversion if making into web app
end = 1521597955
start = 1521511555
lat = 37.623317
lon = -121.756267
url="http://history.openweathermap.org/data/2.5/history/city?lat="\
+str(lat)+"&lon="+str(lon)+"&type=hour&start="+str(start)+"&end="+str(end)+"appid=" + api_key

# %%
url
# Out:
# 'http://history.openweathermap.org/data/2.5/history/city?lat=37.623317&lon=-121.756267&type=hour&start=1521511555&end=1521597955appid=d9f788ccd230de9dfedc79a53db72d7f'

# %%
+ "appid=" + api_key +

# %%
celcius_url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=d9f788ccd230de9dfedc79a53db72d7f&q=Bujumbura&units=metric'
