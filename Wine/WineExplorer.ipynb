# %%
import pandas as pd

# %%
ratings = pd.read_csv("wine_ratings.csv", encoding = "utf-16")

# %%
ratings
# Out:
#            appell_city appell_country                  appell_region  \
# 0            Argentina      Argentina               Mendoza Province
# 1            Argentina      Argentina               Mendoza Province
# 2     Mendoza Province      Argentina                      Tupungato
# 3     Mendoza Province      Argentina                        Mendoza
# 4     Mendoza Province      Argentina                        Mendoza
# 5     Mendoza Province      Argentina                        Mendoza
# 6     Mendoza Province      Argentina                      Tupungato
# 7     Mendoza Province      Argentina                        Mendoza
# 8     Mendoza Province      Argentina                     Uco Valley
# 9     Mendoza Province      Argentina                   Valle de Uco
# 10    Mendoza Province      Argentina                  Luján de Cuyo
# 11    Mendoza Province      Argentina                        Mendoza
# 12    Mendoza Province      Argentina                     Uco Valley
# ...

# %%
coords = ratings[["lat","lon","appell_region"]]

# %%
lol = coords.values.tolist()
lol
# Out:
# [[39.4685921, -0.3793492, 'Mendoza Province'],
#  [39.4685921, -0.3793492, 'Mendoza Province'],
#  [-33.3723648, -69.1479533, 'Tupungato'],
#  [-32.8897294, -68.8442956, 'Mendoza'],
#  [-32.8897294, -68.8442956, 'Mendoza'],
#  [-32.8897294, -68.8442956, 'Mendoza'],
#  [-33.3723648, -69.1479533, 'Tupungato'],
#  [-32.8897294, -68.8442956, 'Mendoza'],
#  [-34.578847100000004, -58.43530820000001, 'Uco Valley'],
#  [nan, nan, 'Valle de Uco'],
#  [-33.1086856, -69.01844859999999, 'Luján de Cuyo'],
#  [-32.8897294, -68.8442956, 'Mendoza'],
#  [-34.578847100000004, -58.43530820000001, 'Uco Valley'],
#  [-34.578847100000004, -58.43530820000001, 'Uco Valley'],
#  [-33.3723648, -69.1479533, 'Tupungato'],
#  [-47.1860304, -66.31076130334371, 'San Juan'],
#  [-47.1860304, -66.31076130334371, 'San Juan'],
#  [-34.6452384, -58.3930969, 'Buenos Aires'],
#  [-24.7761086, 134.755, 'Australia'],
#  [-24.7761086, 134.755, 'Australia'],
#  [-33.740658399999994, 150.9630074, 'Adelaide Hills'],
# ...

# %%
df = pd.read_csv('wine_ratings.csv', encoding="utf-16")
iso3 = []

for i in df.appell_country.tolist():
    if i == 'US':
        iso3.append('USA')
    elif i == 'France':
        iso3.append('FRA')
    elif i == 'Chile':
        iso3.append('CHL')
    elif i == 'New Zealand':
        iso3.append('NZL')
    elif i == 'Italy':
        iso3.append('ITA')
    elif i == 'South Africa':
        iso3.append('ZAF')
    elif i == 'Austria':
        iso3.append('AUT')
    elif i == 'Argentina':
        iso3.append('ARG')
    elif i == 'Spain':
        iso3.append('ESP')
    elif i == 'Portugal':
        iso3.append('PRT')
    elif i == 'Australia':
        iso3.append('AUS')
    elif i == 'Romania':
        iso3.append('ROU')
    elif i == 'Bulgaria':
        iso3.append('BGR')
    elif i == 'Israel':
        iso3.append('ISR')
    elif i == 'Canada':
        iso3.append('CAN')
    elif i == 'Greece':
        iso3.append('GRC')
    elif i == 'Slovenia':
        iso3.append('SVN')
    elif i == 'Morocco':
        iso3.append('MAR')
    elif i == 'Germany':
        iso3.append('DEU')
    elif i == 'India':
        iso3.append('IND')
    elif i == 'Uruguay':
        iso3.append('URY')
    elif i == 'Moldova':
        iso3.append('MDA')
    else:
        print(i + ": didn't catch")

# %%
iso3
# Out:
# ['ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'ARG',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUS',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'AUT',
#  'BGR',
#  'BGR',
#  'BGR',
#  'BGR',
#  'CAN',
#  'CAN',
#  'CAN',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
#  'CHL',
# ...
